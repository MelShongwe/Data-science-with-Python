# %%
import pandas as pd

# %%
table1=pd.read_csv("table1.csv")

# %%
table1.head()
# Out:
#   Country   Medal  Count
# 0     AFG  Bronze      2
# 1     AHO  Silver      1
# 2     ALG  Bronze      8
# 3     ALG    Gold      5
# 4     ALG  Silver      2

# %%
table1.pivot(index="Country",columns="Medal",values="Count")
# Out:
# Medal    Bronze   Gold  Silver
# Country
# AFG         2.0    NaN     NaN
# AHO         NaN    NaN     1.0
# ALG         8.0    5.0     2.0
# ANZ         5.0   20.0     4.0
# ARG        91.0   69.0    99.0
# ...         ...    ...     ...
# VIE         NaN    NaN     2.0
# YUG       118.0  143.0   174.0
# ZAM         1.0    NaN     1.0
# ZIM         1.0   18.0     4.0
# ZZX        10.0   23.0    15.0
#
# [147 rows x 3 columns]

# %%
data_12=pd.read_csv("table_2012.csv")

# %%
data_12.head()
# Out:
#   Country  Gold  Silver  Bronze
# 0     USA   147      57      46
# 1     CHN    56      44      28
# 2     GBR    48      30      48
# 3     RUS    47      32      51
# 4     GER    45      28      21

# %%
new_data=data_12.melt(id_vars="Country",value_vars=["Gold","Silver","Bronze"])

# %%
new_data.head()
# Out:
#   Country variable  value
# 0     USA     Gold    147
# 1     CHN     Gold     56
# 2     GBR     Gold     48
# 3     RUS     Gold     47
# 4     GER     Gold     45
